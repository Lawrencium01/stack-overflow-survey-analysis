# %%
import os

# %%
# to get current working directory
os.getcwd()
# Out:
# 'C:\\Users\\HP\\FreeCodeCamp Python for Data Analytics'

# %%
#os.listdir(os.getcwd())
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  '1_Numpy.ipynb',
#  '2_Interacting with OS and filesystem.ipynb',
#  'Branching if, else, elif.ipynb',
#  'climate_result.txt',
#  'data',
#  'first_steps_with_python.ipynb',
#  'Functions and Scope.ipynb',
#  'Variables_and_data_types.ipynb']

# %%
os.listdir('/usr') #absolute path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 os.listdir('/usr')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/usr'

# %%
os.makedirs('./data', exist_ok = True)

# %%
'data' in os.listdir('.')
# Out:
# True

# %%
os.listdir('./data')
# Out:
# []

# %%
file = open(r"C:\Users\HP\FreeCodeCamp Python for Data Analytics\data\Python.txt", mode = 'r', encoding = 'UTF8', newline = '')

# %%
file_content = file.read()

# %%
print(file_content)
# Out:
# tuples are immutable i.e they cannot be modified
#
# to iterates through a tuple we use zip
#
# we use dtype to check for the data type
#
# for identity matrix in numpy we use np.eye

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
with open(r"C:\Users\HP\FreeCodeCamp Python for Data Analytics\climate_result.txt", mode = 'r', encoding = 'UTF8') as file2:
    file_content = file2.read()
    print(file_content)
# Out:
# temperature,rainfall,humidity,yeild_apples
# 73.00 67.00 43.00 56.80
# 91.00 88.00 64.00 76.90
# 87.00 134.00 58.00 81.90
# 102.00 43.00 37.00 57.70
# 69.00 96.00 70.00 74.90

# %%
file2.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 file2.read()
#
# ValueError: I/O operation on closed file.

# %%
with open(r"C:\Users\HP\FreeCodeCamp Python for Data Analytics\climate_result.txt", mode = 'r', encoding = 'UTF8') as file3:
    file3_lines = file3.readlines()

# %%
file3_lines
# Out:
# ['temperature,rainfall,humidity,yeild_apples\n',
#  '73.00 67.00 43.00 56.80\n',
#  '91.00 88.00 64.00 76.90\n',
#  '87.00 134.00 58.00 81.90\n',
#  '102.00 43.00 37.00 57.70\n',
#  '69.00 96.00 70.00 74.90\n']

# %%
file3_lines[0].strip()
# Out:
# 'temperature,rainfall,humidity,yeild_apples'

# %%
file = open(r"C:\Users\HP\FreeCodeCamp Python for Data Analytics\loan.txt", mode = 'r', encoding = 'UTF8', newline = '')

# %%
file_content = file.readlines()

# %%
loan1 = {
    'amount' : 828400,
    'duration': 120,
    'rate': 0.11,
    'down_payment':100000
}

# %%
def parse_headers(header_line):
    return header_line.strip().split(',')

# %%
file_content[0]
# Out:
# 'amount,duration,rate,down_payment\r\n'

# %%
headers = parse_headers(file_content[0])

# %%
headers
# Out:
# ['amount', 'duration', 'rate', 'down_payment']

# %%
def parse_values(data_line):
    values = []
    for item in data_line.strip().split(','):
        values.append(float(item))
    return values

# %%
file_content[1]
# Out:
# '828400,120,0.11,100000\r\n'

# %%
parse_values(file_content[1])
# Out:
# [828400.0, 120.0, 0.11, 100000.0]

# %%
parse_values(file_content[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 parse_values(file_content[2])
#
# Cell In[61], line 4, in parse_values(data_line)
#       2 values = []
#       3 for item in data_line.strip().split(','):
# ----> 4     values.append(float(item))
#       5 return values
#
# ValueError: could not convert string to float: ''

# %%
file_content[2].strip().split(',')
# Out:
# ['4633400', '240', '0.06', '']

# %%
def parse_values(data_line):
    values = []
    for item in data_line.strip().split(','):
        if item == '':
            values.append(0.0)
        else:
            values.append(float(item))
    return values

# %%
parse_values(file_content[2])
# Out:
# [4633400.0, 240.0, 0.06, 0.0]

# %%
def create_item_dict(values, headers):
    result = {}
    for value,header in zip(values, headers):
        result[header]  = value
    return result

# %%
def read_csv(path):
    result = []
    with open(path, 'r') as f:
        lines = f.readlines()
        # Parse the header
        headers = parse_headers(lines[0])
        #Loop over the remaining lines
        for data_line in lines[1:]:
            values = parse_values(data_line)
            # create a dictionary using values and headers
            item_dict = create_item_dict(values,headers)
            # add the dictionary to result
            result.append(item_dict)
    return result

# %%
read_csv(r"C:\Users\HP\FreeCodeCamp Python for Data Analytics\loan.txt")
# Out:
# [{'amount': 828400.0,
#   'duration': 120.0,
#   'rate': 0.11,
#   'down_payment': 100000.0},
#  {'amount': 4633400.0, 'duration': 240.0, 'rate': 0.06, 'down_payment': 0.0},
#  {'amount': 42900.0, 'duration': 90.0, 'rate': 0.08, 'down_payment': 8900.0},
#  {'amount': 983000.0, 'duration': 16.0, 'rate': 0.14, 'down_payment': 0.0},
#  {'amount': 15230.0, 'duration': 48.0, 'rate': 0.07, 'down_payment': 4300.0}]
