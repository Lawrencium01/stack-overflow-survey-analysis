# %% [markdown]
# # Data Visualization using Python, Matplotlib and Searborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples)

# %%
#plt.show()
plt.plot(yield_apples);

# %%
year = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(year, yield_apples);

# %%
plt.plot(year, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yeilds in Kanto')
plt.legend(['Apples','Oranges']);

# %%
plt.plot(years, apples, marker = 'o')
plt.plot(years, oranges, marker = 'x')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yeilds in Kanto')
plt.legend(['Apples','Oranges']);

# %%
plt.plot(years, apples, marker = 's', c = 'b', ls = '-', lw = 2, ms = 8, mew = 2, mec = 'navy')
plt.plot(years, oranges, marker = 'o', c = 'r', ls = '--', lw = 3, ms = 10, alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yeilds in Kanto')
plt.legend(['Apples','Oranges']);

# %% [markdown]
# **fmt = '[marker][line][color]'**

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yeilds in Kanto')
plt.legend(['Apples','Oranges']);

# %%
plt.figure(figsize = (12,6))

plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hectare)');

# %%
sns.set_style('whitegrid')

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yeilds in Kanto')
plt.legend(['Apples','Oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yeilds in Kanto')
plt.legend(['Apples','Oranges']);

# %%
import matplotlib

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Scatter Plot

# %%
flowers_df = sns.load_dataset('iris')

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df['sepal_length'], flowers_df['sepal_width'])

# %%
flowers_df.plot(kind = 'scatter', x = 'sepal_length', y = 'sepal_width');

# %%
sns.scatterplot(data = flowers_df,x = 'sepal_length', y = 'sepal_width' );

# %%
sns.scatterplot(data = flowers_df,x = 'sepal_length', y = 'sepal_width', hue = 'species', s = 100 );

# %%
plt.figure(figsize = (20,10))
plt.title('Sepal Dimensions')

sns.scatterplot(data = flowers_df,x = 'sepal_length', y = 'sepal_width', hue = 'species', s = 100 );

# %%
# matplotlib.rcParams

# %% [markdown]
# ## Histogram

# %%
flowers_df = sns.load_dataset('iris')

# %%
flowers_df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flowers_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.set_style('darkgrid')

# %%
plt.title('Distribution of Sepal Width')
plt.hist(flowers_df['sepal_width']);

# %%
plt.hist(flowers_df['sepal_width'], bins = 5);

# %%
import numpy as np

np.arange(2,5, 0.25) # not including 5
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.hist(flowers_df['sepal_width'], bins = np.arange(2,5,0.25));

# %%
# Bins of unequal interval

plt.hist(flowers_df['sepal_width'], bins = [1,3,4,4.5]);

# %%
setosa_df = flowers_df[flowers_df['species'] == 'setosa']
versicolor_df = flowers_df[flowers_df['species'] == 'versicolor']
virginica_df = flowers_df[flowers_df['species'] == 'virginica']

# %%
plt.hist(setosa_df['sepal_width'], bins = np.arange(2,5,0.25), alpha = 0.4)
plt.hist(versicolor_df['sepal_width'], bins = np.arange(2,5,0.25), alpha = 0.4)
plt.legend(['Setosa','Versicolor']);

# %%
# Stacking histogram on top of each other
plt.hist([setosa_df['sepal_width'],virginica_df['sepal_width'],versicolor_df['sepal_width']], bins = np.arange(2,5,0.25), stacked = True)
plt.legend(['Setosa','Virginica','Versicolor']);

# %% [markdown]
# ## Bar Chart

# %%
years = range(2000,2006)
apples = [0.35,0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges);

# %%
plt.plot(years, apples, 'o--r');

# %%
plt.bar(years, oranges)
plt.plot(years, apples, 'o--r')
plt.title('Yield of Oranges');

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom = apples)
# Out:
# <BarContainer object of 6 artists>

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg_bf = tips_df.groupby('day', observed = False)['total_bill'].mean()

# %%
plt.bar(bill_avg_bf.index, bill_avg_bf.values);

# %%
sns.barplot(data = tips_df, x = 'day', y = 'total_bill');

# %%
sns.barplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'sex');

# %%
## you can make the bar horizontal in seaborn by switching the axis

# %%
sns.barplot(data = tips_df, x = 'total_bill', y = 'day', hue = 'sex');

# %% [markdown]
# ## Heatmap

# %%
flights_df = sns.load_dataset('flights').pivot(index = 'month', columns = 'year', values = 'passengers')
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title('No of Passengers (1000s)')
sns.heatmap(flights_df);

# %%
plt.title('No of Passengers (1000s)')
sns.heatmap(flights_df, cmap = 'Blues', annot = True, fmt = 'd');

# %%
from PIL import Image

# %%
img = Image.open(r"C:\Users\HP\Downloads\Audit and Compliance.jpg")

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x359>

# %%
plt.grid(False)
plt.title('Audit Compliance')
plt.axis('off')
plt.imshow(img);

# %%
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (359, 612, 3)

# %% [markdown]
# ## Practice

# %%
from PIL import Image

# %%
img = Image.open(r"C:\Users\HP\Downloads\Accounting_firm_Audit_Compliance (1).jpg")

# %%
plt.imshow(img);

# %%
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (780, 1400, 3)

# %% [markdown]
# ## Plotting multiple charts in a grid

# %%
fig, axes = plt.subplots(2,3, figsize = (12,9))

axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].plot(years, apples, 's-b')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].set_title('Yield of oranges')
axes[0,0].legend(['Apples','Oranges'])

axes[0,1].set_title('Sepal length vs. width')
sns.scatterplot(x = flowers_df['sepal_length'], y = flowers_df['sepal_width'], hue = flowers_df['species'], s = 100, ax = axes[0,1])

plt.tight_layout(pad = 2)

# %%
axes.shape
# Out:
# (2, 3)
