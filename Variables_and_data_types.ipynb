# %% [markdown]
# ## Variables and Data Types

# %%
my_favourite_color = 'blue'

my_favourite_color
# Out:
# 'blue'

# %%
color1, color2, color3 = 'red', 'blue', 'green'
color1
# Out:
# 'red'

# %%
color2
# Out:
# 'blue'

# %%
color3
# Out:
# 'green'

# %%
color4 = color5 = color6 = 'magenta'
color4
# Out:
# 'magenta'

# %%
color5
# Out:
# 'magenta'

# %%
color6
# Out:
# 'magenta'

# %%
my_favourite_color = 'red'
my_favourite_color
# Out:
# 'red'

# %%
counter = 10
counter = counter + 1
counter
# Out:
# 11

# %%
counter = 10
counter += 1
counter
# Out:
# 11

# %%
a_variable = 23
is_today_saturday = False
my_favorite_car = 'Ferrari'
the_3musketeers = ['Athos','Porthos','Aramis']

# %% [markdown]
# ## Built-in data types in Python

# %%
type(a_variable)
# Out:
# int

# %%
type(is_today_saturday)
# Out:
# bool

# %%
type(my_favorite_car)
# Out:
# str

# %%
type(the_3musketeers)
# Out:
# list

# %%
a_large_negative_number = -1223556376878675345692475647

# %%
type(a_large_negative_number)
# Out:
# int

# %%
pi = 3.142

# %%
type(pi)
# Out:
# float

# %%
a_number = 3.0

# %%
type(a_number)
# Out:
# float

# %%
one_hundredth = 1e-2

# %%
one_hundredth
# Out:
# 0.01

# %%
type(one_hundredth)
# Out:
# float

# %%
avogadro_number = 6.02e23

# %%
avogadro_number
# Out:
# 6.02e+23

# %%
type(avogadro_number)
# Out:
# float

# %%
int(one_hundredth)
# Out:
# 0

# %%
int(avogadro_number)
# Out:
# 601999999999999995805696

# %%
float(a_large_negative_number)
# Out:
# -1.2235563768786753e+27

# %%
int(pi)
# Out:
# 3

# %%
type(45 * 3.0)
# Out:
# float

# %%
type(45 * 3)
# Out:
# int

# %%
type(10/3)
# Out:
# float

# %%
type(10/3.0)
# Out:
# float

# %%
type(10//2)
# Out:
# int

# %% [markdown]
# ## Boolean

# %%
is_today_tuesday = True

# %%
type(is_today_tuesday)
# Out:
# bool

# %%
5 + False #False is represented as 0
# Out:
# 5

# %%
5.0 + True #True is represented as 1
# Out:
# 6.0

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(range(0))
# Out:
# False

# %%
today = 'Tuesday'

type(today)
# Out:
# str

# %%
my_favourtite_movie = 'two and half men'

# %%
len(my_favourtite_movie)
# Out:
# 16

# %%
multiline = """a
b"""

# %%
print(multiline)
# Out:
# a
# b

# %%
len(multiline)
# Out:
# 3

# %%
list(multiline)
# Out:
# ['a', '\n', 'b']

# %%
today = 'Saturday'

today[0]
# Out:
# 'S'

# %%
today[3]
# Out:
# 'u'

# %%
today[5]
# Out:
# 'd'

# %%
today[5:8]
# Out:
# 'day'

# %%
'day' in today
# Out:
# True

# %%
full_name = 'Lawrence Emmanuel'

greeting = 'Hello'

# %%
print(greeting + " " + full_name + "!")
# Out:
# Hello Lawrence Emmanuel!

# %%
today.lower()
# Out:
# 'tuesday'

# %%
today.upper()
# Out:
# 'TUESDAY'

# %%
today.capitalize()
# Out:
# 'Tuesday'

# %%
# help(str)

# %%
another_day = today.replace('Satur','Wednes', count = -1)
another_day
# Out:
# 'Tuesday'

# %%
today
# Out:
# 'Tuesday'

# %%
'sun,mon,tue,wed,thur,fri,satur'.split(',')
# Out:
# ['sun', 'mon', 'tue', 'wed', 'thur', 'fri', 'satur']

# %%
a_long_line = '    Grateful to the lord for letting me see another beautiful day in the month of may....'
a_long_line_stripped = a_long_line.strip('. ')

# %%
a_long_line_stripped
# Out:
# 'Grateful to the lord for letting me see another beautiful day in the month of may'

# %%
cost_of_ice_bag = 1.25
profit_margin = 0.2
number_of_bags = 500
total_profit = (cost_of_ice_bag * profit_margin) * number_of_bags
output_message = f"If a grocery store sells ice bags at ${cost_of_ice_bag} per bag , \nwith a profit margin of {profit_margin},then the total profit it makes by selling {number_of_bags} is ${total_profit}"
print(output_message)
# Out:
# If a grocery store sells ice bags at $1.25 per bag ,
# with a profit margin of 0.2,then the total profit it makes by selling 500 is $125.0

# %%
str(23)
# Out:
# '23'

# %%
str(23.43)
# Out:
# '23.43'

# %%
the_3musketeerss = str(the_3musketeers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 the_3musketeerss = str(the_3musketeers)
#
# NameError: name 'the_3musketeers' is not defined

# %%
import ast
the_3musketeerss = ast.literal_eval(the_3musketeerss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 import ast
# ----> 2 the_3musketeerss = ast.literal_eval(the_3musketeerss)
#
# NameError: name 'the_3musketeerss' is not defined

# %%
the_3musketeerss
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %%
first_name = 'John'

# %%
first_name == 'Doe'
# Out:
# False

# %%
first_name == 'John'
# Out:
# True

# %%
first_name != 'Jane'
# Out:
# True

# %% [markdown]
# ## List

# %%
fruits = ['apple','banana','cherry']

# %%
type(fruits)
# Out:
# list

# %%
a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
empty_list = []

# %%
type(empty_list)
# Out:
# list

# %%
bool([])
# Out:
# False

# %%
len(fruits)
# Out:
# 3

# %%
len(a_list)
# Out:
# 6

# %%
len(empty_list)
# Out:
# 0

# %%
fruits[2]
# Out:
# 'cherry'

# %%
fruits[-1]
# Out:
# 'cherry'

# %%
a_list[4][1]
# Out:
# 'banana'

# %%
fruits[1] = 'Mango'

# %%
fruits
# Out:
# ['apple', 'Mango', 'cherry']

# %%
# help(list)

# %%
list.__getitem__(fruits,0)
# Out:
# 'apple'

# %%
fruits.append('Cashew')

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'Cashew']

# %%
# help(list)

# %%
fruits.insert(1,'Pawpaw')

# %%
fruits
# Out:
# ['apple', 'Pawpaw', 'banana', 'cherry', 'Cashew']

# %%
fruits.remove('Mango')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fruits.remove('Mango')
#
# ValueError: list.remove(x): x not in list

# %%
fruits
# Out:
# ['apple', 'Pawpaw', 'banana', 'cherry', 'Cashew']

# %%
# help(list)

# %%
fruits.pop(3)
# Out:
# 'cherry'

# %%
fruits
# Out:
# ['apple', 'Pawpaw', 'banana', 'Cashew']

# %%
'pineapple' in fruits
# Out:
# False

# %%
'apple' in fruits
# Out:
# True

# %%
more_fruits = fruits + ['mango', 'carrot'] + ['Guava']
more_fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'carrot', 'Guava']

# %%
copied_list = more_fruits.copy()

# %%
copied_list
# Out:
# ['apple', 'Pawpaw', 'banana', 'Cashew', 'mango', 'carrot', 'Guava']

# %% [markdown]
# ## Tuples

# %%
fruits = ('cherry','mango','apple')

# %%
len(fruits)
# Out:
# 3

# %%
fruits[2]
# Out:
# 'apple'

# %%
fruits[-3]
# Out:
# 'cherry'

# %%
'mango' in fruits
# Out:
# True

# %% [markdown]
# #### Tupples are immutable they cannot be changed

# %%
# help(tuple)

# %% [markdown]
# ### Dictionaries

# %%
person1 = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

# %%
person1.items()
# Out:
# dict_items([('name', 'John Doe'), ('sex', 'Male'), ('age', 32), ('married', True)])

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])

# %%
person1['sex']
# Out:
# 'Male'

# %%
# help(dict)

# %%
person1.update({'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True,
    'level': 400    
               })

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True, 'level': 400}

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...

# %%
person1.popitem()
# Out:
# ('level', 400)

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
'level' in person1
# Out:
# False

# %%
person1['name'] = 'Lawrence Emmanuel'

# %%
person1
# Out:
# {'name': 'Lawrence Emmanuel', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1['level'] = 400

# %%
person1
# Out:
# {'name': 'Lawrence Emmanuel',
#  'sex': 'Male',
#  'age': 32,
#  'married': True,
#  'level': 400}
