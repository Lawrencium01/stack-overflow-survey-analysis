# %%
a_number = 35

if a_number % 2 == 0:
    print('we are inside an if block')
    print(f'the given number {a_number} is even')
else:
    print('the number is odd')
# Out:
# the number is odd

# %%
another_number = 33
if another_number % 2 == 0:
    print('we are inside an if block')
else:
    print(f'the given number {a_number} is odd')
# Out:
# the given number 34 is odd

# %%
the_3_musketeers = ('Athos', 'Porthos', 'Aramis')

# %%
a_candidate = "d'artagnan"

# %%
if a_candidate in the_3_musketeers:
    print(f'{a_candidate} is a musketeers')
else:
    print(f'{a_candidate} is not a musketeers')
# Out:
# d'artagnan is not a musketeers

# %%
today = 'Wednesday'

# %%
if today == 'Sunday':
    print('Today is the day of the sun')
elif today == 'Monday':
    print('Today is the day of the moon')
elif today == 'Tuesday':
    print('Today is the day of the war')
elif today == 'Wednesday':
    print('Today is the day of the supreme deity')
elif today == 'Thrsday':
    print('Today is the day of the moon')
elif today == 'Friday':
    print('Today is the day of the moon')
# Out:
# Today is the day of the supreme deity

# %%
a_number = 49

# %%
if a_number % 2 == 0:
    print(f'{a_number} is divisible by 2')
elif a_number % 3 == 0:
    print(f'{a_number} is divisible by 3')
elif a_number % 5 == 0:
    print(f'{a_number} is divisible by 5')
else:
    print(f'{a_number} is not divisible by 2,3 or 5')
# Out:
# 49 is not divisible by 2,3 or 5

# %%
if bool(''):
    print('The condition is evaluated to True')
else:
    print('The condition is evaluated to False')
# Out:
# The condition is evaluated to False

# %%
my_list = []

if my_list:
    print('Contained list')
else:
    print('Empty list')
# Out:
# Empty list

# %%
i = 0
while(i <= 8):
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
i = 2
while(i < 100):
    print(i)
    i = i * 2
# Out:
# 2
# 4
# 8
# 16
# 32
# 64

# %%
result = 1
i = 1

while(i <= 100):
    result = result * i
    i = i + 1
print(f'The factorial of 100 is {result}')
# Out:
# The factorial of 100 is 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
# Factorial of 1000
# %time

result = 1
i = 1

while(i <= 1000):
    result = result * i
    i = i + 1
print(f'The factorial of 1000 is {result}')
# Out:
# CPU times: total: 0 ns
# Wall time: 5.72 μs
# The factorial of 1000 is ...

# %%
result = 1
i = 1

while (i < 100):
    result *= i
    if i == 42:
        print('Magic number 42 reached, stop execution...')
        break
    i += 1
print('i',i)
print('result', result)
# Out:
# Magic number 42 reached, stop execution...
# i 42
# result 1405006117752879898543142606244511569936384000000000

# %%
days = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

for day in days:
    print(day)
# Out:
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday

# %%
for char in 'Monday':
    print(char)
# Out:
# M
# o
# n
# d
# a
# y

# %%
for fruit in ['Apple','Mango','Guava']:
    print(fruit)
# Out:
# Apple
# Mango
# Guava

# %%
result = 1
i = 1

while (i <= 100):
    result *= i
    if i == 42:
        print('Magic Number 42')
        break

    i += 1
print(f'the factorial of 42 is {result}')
# Out:
# Magic Number 42
# the factorial of 42 is 1405006117752879898543142606244511569936384000000000

# %%
person = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

# %%
for keys, values in person.items():
    print(keys,'->',values)
# Out:
# name -> John Doe
# sex -> Male
# age -> 32
# married -> True

# %%
for i in range(7):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(3,10):
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(3,14,4):
    print(i)
# Out:
# 3
# 7
# 11

# %%
a_list = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

for i in range(len(a_list)):
    print(i,'->',a_list[i])
# Out:
# 0 -> Sunday
# 1 -> Monday
# 2 -> Tuesday
# 3 -> Wednesday
# 4 -> Thursday
# 5 -> Friday
# 6 -> Saturday

# %%
weekdays = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

for days in weekdays:
    if days == 'Thursday':
        print('I dont work beyond thursday')
        break
    print(days)
# Out:
# Sunday
# Monday
# Tuesday
# Wednesday
# I dont work beyond thursday

# %%
for days in weekdays:
    if days == 'Thursday':
        print('I dont work beyond thursday')
        continue
    print(days)
# Out:
# Sunday
# Monday
# Tuesday
# Wednesday
# I dont work beyond thursday
# Friday
# Saturday

# %%
for days in weekdays:
    pass

# %%
days = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
fruits = ['apple','mango','cashew','banana']

for day in days:
    for fruit in fruits:
        print('on', day,'I eat fruits like',fruit)
# Out:
# on Sunday I eat fruits like apple
# on Sunday I eat fruits like mango
# on Sunday I eat fruits like cashew
# on Sunday I eat fruits like banana
# on Monday I eat fruits like apple
# on Monday I eat fruits like mango
# on Monday I eat fruits like cashew
# on Monday I eat fruits like banana
# on Tuesday I eat fruits like apple
# on Tuesday I eat fruits like mango
# on Tuesday I eat fruits like cashew
# on Tuesday I eat fruits like banana
# on Wednesday I eat fruits like apple
# on Wednesday I eat fruits like mango
# on Wednesday I eat fruits like cashew
# on Wednesday I eat fruits like banana
# on Thursday I eat fruits like apple
# on Thursday I eat fruits like mango
# on Thursday I eat fruits like cashew
# on Thursday I eat fruits like banana
# on Friday I eat fruits like apple
# on Friday I eat fruits like mango
# on Friday I eat fruits like cashew
# on Friday I eat fruits like banana
# on Saturday I eat fruits like apple
# on Saturday I eat fruits like mango
# ...

# %%
result = 1
i = 1

while(i <= 100):
    result = result * i
    i = i + 1
print(result)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000
